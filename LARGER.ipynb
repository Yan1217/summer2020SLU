# %% [markdown]
# ## tar 00-tar03
# ## test acc :1

# %%
import matplotlib.pyplot as plt
import pandas as pd

df = pd.read_csv('history_large.csv')

acc = df['acc']


val_acc = df['val_acc']
loss = df['loss']
val_loss = df['val_loss']

epochs = range(len(acc))

plt.plot(epochs, acc, 'bo', label='Training acc')
plt.plot(epochs, val_acc, 'b', label='Validation acc')
plt.title('Training and validation accuracy')
plt.legend()

plt.figure()

plt.plot(epochs, loss, 'bo', label='Training loss')
plt.plot(epochs, val_loss, 'b', label='Validation loss')
plt.title('Training and validation loss')
plt.legend()

plt.show()

# %% [markdown]
# ## test acc 0.99-random seed 2:

# %%
import matplotlib.pyplot as plt
import pandas as pd

df = pd.read_csv('history_large2.csv')

acc = df['acc']


val_acc = df['val_acc']
loss = df['loss']
val_loss = df['val_loss']

epochs = range(len(acc))

plt.plot(epochs, acc, 'bo', label='Training acc')
plt.plot(epochs, val_acc, 'b', label='Validation acc')
plt.title('Training and validation accuracy')
plt.legend()

plt.figure()

plt.plot(epochs, loss, 'bo', label='Training loss')
plt.plot(epochs, val_loss, 'b', label='Validation loss')
plt.title('Training and validation loss')
plt.legend()

plt.show()

# %% [markdown]
# ## tar 04-tar07
# ## test 0.907

# %%
import matplotlib.pyplot as plt
import pandas as pd

df = pd.read_csv('history_large3.csv')

acc = df['acc']


val_acc = df['val_acc']
loss = df['loss']
val_loss = df['val_loss']

epochs = range(len(acc))

plt.plot(epochs, acc, 'bo', label='Training acc')
plt.plot(epochs, val_acc, 'b', label='Validation acc')
plt.title('Training and validation accuracy')
plt.legend()

plt.figure()

plt.plot(epochs, loss, 'bo', label='Training loss')
plt.plot(epochs, val_loss, 'b', label='Validation loss')
plt.title('Training and validation loss')
plt.legend()

plt.show()

# %% [markdown]
# ## 04-07 epoc:50
# ## test acc : 0.998

# %%
import matplotlib.pyplot as plt
import pandas as pd

df = pd.read_csv('history_large4-7.csv')

acc = df['acc']


val_acc = df['val_acc']
loss = df['loss']
val_loss = df['val_loss']

epochs = range(len(acc))

plt.plot(epochs, acc, 'bo', label='Training acc')
plt.plot(epochs, val_acc, 'b', label='Validation acc')
plt.title('Training and validation accuracy')
plt.legend()

plt.figure()

plt.plot(epochs, loss, 'bo', label='Training loss')
plt.plot(epochs, val_loss, 'b', label='Validation loss')
plt.title('Training and validation loss')
plt.legend()

plt.show()

# %% [markdown]
# ## tar 07-11 pochs:1000
# ## test acc: 0.999

# %%
import matplotlib.pyplot as plt
import pandas as pd

df = pd.read_csv('history_large4-7-1000.csv')

acc = df['acc']


val_acc = df['val_acc']
loss = df['loss']
val_loss = df['val_loss']

epochs = range(len(acc))

plt.plot(epochs, acc, 'bo', label='Training acc')
plt.plot(epochs, val_acc, 'b', label='Validation acc')
plt.title('Training and validation accuracy')
plt.legend()

plt.figure()

plt.plot(epochs, loss, 'bo', label='Training loss')
plt.plot(epochs, val_loss, 'b', label='Validation loss')
plt.title('Training and validation loss')
plt.legend()

plt.show()

# %% [markdown]
# ## tar 09-11 test acc: 0.996

# %%
import matplotlib.pyplot as plt
import pandas as pd

df = pd.read_csv('history_large09-11.csv')

acc = df['acc']


val_acc = df['val_acc']
loss = df['loss']
val_loss = df['val_loss']

epochs = range(len(acc))

plt.plot(epochs, acc, 'bo', label='Training acc')
plt.plot(epochs, val_acc, 'b', label='Validation acc')
plt.title('Training and validation accuracy')
plt.legend()

plt.figure()

plt.plot(epochs, loss, 'bo', label='Training loss')
plt.plot(epochs, val_loss, 'b', label='Validation loss')
plt.title('Training and validation loss')
plt.legend()

plt.show()

# %% [markdown]
# ## tar9-11 epoc:50

# %%
import matplotlib.pyplot as plt
import pandas as pd

df = pd.read_csv('history_large9-11-2.csv')

acc = df['acc']


val_acc = df['val_acc']
loss = df['loss']
val_loss = df['val_loss']

epochs = range(len(acc))

plt.plot(epochs, acc, 'bo', label='Training acc')
plt.plot(epochs, val_acc, 'b', label='Validation acc')
plt.title('Training and validation accuracy')
plt.legend()

plt.figure()

plt.plot(epochs, loss, 'bo', label='Training loss')
plt.plot(epochs, val_loss, 'b', label='Validation loss')
plt.title('Training and validation loss')
plt.legend()

plt.show()

# %% [markdown]
# ## Test dog-cat
# ## test acc: 0.50

# %%
import matplotlib.pyplot as plt
import pandas as pd

df = pd.read_csv('history_test_cat_dog.csv')

acc = df['acc']


val_acc = df['val_acc']
loss = df['loss']
val_loss = df['val_loss']

epochs = range(len(acc))

plt.plot(epochs, acc, 'bo', label='Training acc')
plt.plot(epochs, val_acc, 'b', label='Validation acc')
plt.title('Training and validation accuracy')
plt.legend()

plt.figure()

plt.plot(epochs, loss, 'bo', label='Training loss')
plt.plot(epochs, val_loss, 'b', label='Validation loss')
plt.title('Training and validation loss')
plt.legend()

plt.show()

# %% [markdown]
# ## mix with kaggle images
# ## test acc: 0.96

# %%
import matplotlib.pyplot as plt
import pandas as pd

df = pd.read_csv('history_mix.csv')

acc = df['acc']


val_acc = df['val_acc']
loss = df['loss']
val_loss = df['val_loss']

epochs = range(len(acc))

plt.plot(epochs, acc, 'bo', label='Training acc')
plt.plot(epochs, val_acc, 'b', label='Validation acc')
plt.title('Training and validation accuracy')
plt.legend()

plt.figure()

plt.plot(epochs, loss, 'bo', label='Training loss')
plt.plot(epochs, val_loss, 'b', label='Validation loss')
plt.title('Training and validation loss')
plt.legend()

plt.show()

# %% [markdown]
# ## Mix training, kaggle test only:
# ## test acc :0.61

# %%
import matplotlib.pyplot as plt
import pandas as pd

df = pd.read_csv('history_mix_test_k_only.csv')

acc = df['acc']


val_acc = df['val_acc']
loss = df['loss']
val_loss = df['val_loss']

epochs = range(len(acc))

plt.plot(epochs, acc, 'bo', label='Training acc')
plt.plot(epochs, val_acc, 'b', label='Validation acc')
plt.title('Training and validation accuracy')
plt.legend()

plt.figure()

plt.plot(epochs, loss, 'bo', label='Training loss')
plt.plot(epochs, val_loss, 'b', label='Validation loss')
plt.title('Training and validation loss')
plt.legend()

plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd

df = pd.read_csv('history_large_01.csv')

acc = df['acc']


val_acc = df['val_acc']
loss = df['loss']
val_loss = df['val_loss']

epochs = range(len(acc))

plt.plot(epochs, acc, 'bo', label='Training acc')
plt.plot(epochs, val_acc, 'b', label='Validation acc')
plt.title('Training and validation accuracy')
plt.legend()

plt.figure()

plt.plot(epochs, loss, 'bo', label='Training loss')
plt.plot(epochs, val_loss, 'b', label='Validation loss')
plt.title('Training and validation loss')
plt.legend()

plt.show()

# %% [markdown]
# ## test acc : 0.99 tar 04-07

# %%
import matplotlib.pyplot as plt
import pandas as pd

df = pd.read_csv('history_large_02.csv')

acc = df['acc']


val_acc = df['val_acc']
loss = df['loss']
val_loss = df['val_loss']

epochs = range(len(acc))

plt.plot(epochs, acc, 'bo', label='Training acc')
plt.plot(epochs, val_acc, 'b', label='Validation acc')
plt.title('Training and validation accuracy')
plt.legend()

plt.figure()

plt.plot(epochs, loss, 'bo', label='Training loss')
plt.plot(epochs, val_loss, 'b', label='Validation loss')
plt.title('Training and validation loss')
plt.legend()

plt.show()

# %% [markdown]
# ## without dup test acc :0.99

# %%
import matplotlib.pyplot as plt
import pandas as pd

df = pd.read_csv('history_large_03.csv')

acc = df['acc']


val_acc = df['val_acc']
loss = df['loss']
val_loss = df['val_loss']

epochs = range(len(acc))

plt.plot(epochs, acc, 'bo', label='Training acc')
plt.plot(epochs, val_acc, 'b', label='Validation acc')
plt.title('Training and validation accuracy')
plt.legend()

plt.figure()

plt.plot(epochs, loss, 'bo', label='Training loss')
plt.plot(epochs, val_loss, 'b', label='Validation loss')
plt.title('Training and validation loss')
plt.legend()

plt.show()

# %% [markdown]
# ## test acc :0.99

# %%
import matplotlib.pyplot as plt
import pandas as pd

df = pd.read_csv('history_large_2000.csv')

acc = df['acc']


val_acc = df['val_acc']
loss = df['loss']
val_loss = df['val_loss']

epochs = range(len(acc))

plt.plot(epochs, acc, 'bo', label='Training acc')
plt.plot(epochs, val_acc, 'b', label='Validation acc')
plt.title('Training and validation accuracy')
plt.legend()

plt.figure()

plt.plot(epochs, loss, 'bo', label='Training loss')
plt.plot(epochs, val_loss, 'b', label='Validation loss')
plt.title('Training and validation loss')
plt.legend()

plt.show()

# %% [markdown]
# ## 200 training set
# ## test acc: 0.97

# %%
import matplotlib.pyplot as plt
import pandas as pd

df = pd.read_csv('history_large_200.csv')

acc = df['acc']


val_acc = df['val_acc']
loss = df['loss']
val_loss = df['val_loss']

epochs = range(len(acc))

plt.plot(epochs, acc, 'bo', label='Training acc')
plt.plot(epochs, val_acc, 'b', label='Validation acc')
plt.title('Training and validation accuracy')
plt.legend()

plt.figure()

plt.plot(epochs, loss, 'bo', label='Training loss')
plt.plot(epochs, val_loss, 'b', label='Validation loss')
plt.title('Training and validation loss')
plt.legend()

plt.show()
