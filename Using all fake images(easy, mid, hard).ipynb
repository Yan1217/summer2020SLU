# %% [markdown]
# # No augmentation
# ## test acc: 0.5655

# %%
import matplotlib.pyplot as plt
import pandas as pd

df = pd.read_csv('history.csv')

acc = df['acc']


val_acc = df['val_acc']
loss = df['loss']
val_loss = df['val_loss']

epochs = range(len(acc))

plt.plot(epochs, acc, 'bo', label='Training acc')
plt.plot(epochs, val_acc, 'b', label='Validation acc')
plt.title('Training and validation accuracy')
plt.legend()

plt.figure()

plt.plot(epochs, loss, 'bo', label='Training loss')
plt.plot(epochs, val_loss, 'b', label='Validation loss')
plt.title('Training and validation loss')
plt.legend()

plt.show()

# %% [markdown]
# ### The training acc reach 1 after epch 15, but there's is a overfitting ,the training loss reach ti 0 after pech 15

# %% [markdown]
# # After using data augmentation
# test acc :0.621

# %%
import matplotlib.pyplot as plt
import pandas as pd

df = pd.read_csv('historywithaug.csv')

acc = df['acc']


val_acc = df['val_acc']
loss = df['loss']
val_loss = df['val_loss']

epo
chs = range(len(acc))

plt.plot(epochs, acc, 'bo', label='Training acc')
plt.plot(epochs, val_acc, 'b', label='Validation acc')
plt.title('Training and validation accuracy')
plt.legend()

plt.figure()

plt.plot(epochs, loss, 'bo', label='Training loss')
plt.plot(epochs, val_loss, 'b', label='Validation loss')
plt.title('Training and validation loss')
plt.legend()

plt.show()

# %% [markdown]
# ### There is a increasing trand for training acc and a decreasing trend for training loss, however, the validation acc and loos swings a lot.

# %% [markdown]
# ## 12 epochs : no aug
# ## test acc :0.6

# %%
import matplotlib.pyplot as plt
import pandas as pd

df = pd.read_csv('history_large_12.csv')

acc = df['acc']


val_acc = df['val_acc']
loss = df['loss']
val_loss = df['val_loss']

epochs = range(len(acc))

plt.plot(epochs, acc, 'bo', label='Training acc')
plt.plot(epochs, val_acc, 'b', label='Validation acc')
plt.title('Training and validation accuracy')
plt.legend()

plt.figure()

plt.plot(epochs, loss, 'bo', label='Training loss')
plt.plot(epochs, val_loss, 'b', label='Validation loss')
plt.title('Training and validation loss')
plt.legend()

plt.show()

# %% [markdown]
# ## with aug
# ## 0.54

# %%
import matplotlib.pyplot as plt
import pandas as pd

df = pd.read_csv('history_K_12_aug.csv')

acc = df['acc']


val_acc = df['val_acc']
loss = df['loss']
val_loss = df['val_loss']

epochs = range(len(acc))

plt.plot(epochs, acc, 'bo', label='Training acc')
plt.plot(epochs, val_acc, 'b', label='Validation acc')
plt.title('Training and validation accuracy')
plt.legend()

plt.figure()

plt.plot(epochs, loss, 'bo', label='Training loss')
plt.plot(epochs, val_loss, 'b', label='Validation loss')
plt.title('Training and validation loss')
plt.legend()

plt.show()

# %% [markdown]
# ## aug epocs: 500
# ## 0.62

# %%
import matplotlib.pyplot as plt
import pandas as pd

df = pd.read_csv('history_K_500_aug.csv')

acc = df['acc']


val_acc = df['val_acc']
loss = df['loss']
val_loss = df['val_loss']

epochs = range(len(acc))

plt.plot(epochs, acc, 'bo', label='Training acc')
plt.plot(epochs, val_acc, 'b', label='Validation acc')
plt.title('Training and validation accuracy')
plt.legend()

plt.figure()

plt.plot(epochs, loss, 'bo', label='Training loss')
plt.plot(epochs, val_loss, 'b', label='Validation loss')
plt.title('Training and validation loss')
plt.legend()

plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd


df = pd.read_csv('history_K_200_aug.csv')

acc = df['acc']


val_acc = df['val_acc']
loss = df['loss']
val_loss = df['val_loss']

epochs = range(len(acc))

plt.plot(epochs, acc, 'bo', label='Training acc')
plt.plot(epochs, val_acc, 'b', label='Validation acc')
plt.title('Training and validation accuracy')
plt.legend()

plt.figure()

plt.plot(epochs, loss, 'bo', label='Training loss')
plt.plot(epochs, val_loss, 'b', label='Validation loss')
plt.title('Training and validation loss')
plt.legend()

plt.show()

# %% [markdown]
# ## 5.5 100 epoch
# ## 0.62

# %%
import matplotlib.pyplot as plt
import pandas as pd

df = pd.read_csv('history_large_5.5.csv')

acc = df['acc']


val_acc = df['val_acc']
loss = df['loss']
val_loss = df['val_loss']

epochs = range(len(acc))

plt.plot(epochs, acc, 'bo', label='Training acc')
plt.plot(epochs, val_acc, 'b', label='Validation acc')
plt.title('Training and validation accuracy')
plt.legend()

plt.figure()

plt.plot(epochs, loss, 'bo', label='Training loss')
plt.plot(epochs, val_loss, 'b', label='Validation loss')
plt.title('Training and validation loss')
plt.legend()

plt.show()

# %% [markdown]
# ## with aug 5.5
# ## 0.65

# %%
import matplotlib.pyplot as plt
import pandas as pd

df = pd.read_csv('history_K_100_aug_5.5.csv')

acc = df['acc']


val_acc = df['val_acc']
loss = df['loss']
val_loss = df['val_loss']

epochs = range(len(acc))

plt.plot(epochs, acc, 'bo', label='Training acc')
plt.plot(epochs, val_acc, 'b', label='Validation acc')
plt.title('Training and validation accuracy')
plt.legend()

plt.figure()

plt.plot(epochs, loss, 'bo', label='Training loss')
plt.plot(epochs, val_loss, 'b', label='Validation loss')
plt.title('Training and validation loss')
plt.legend()

plt.show()

# %% [markdown]
# ## 2 frozen layers
# ## 0.614

# %%
import matplotlib.pyplot as plt
import pandas as pd

df = pd.read_csv('history_K_100_aug_5.5_3.csv')

acc = df['acc']


val_acc = df['val_acc']
loss = df['loss']
val_loss = df['val_loss']

epochs = range(len(acc))

plt.plot(epochs, acc, 'bo', label='Training acc')
plt.plot(epochs, val_acc, 'b', label='Validation acc')
plt.title('Training and validation accuracy')
plt.legend()

plt.figure()

plt.plot(epochs, loss, 'bo', label='Training loss')
plt.plot(epochs, val_loss, 'b', label='Validation loss')
plt.title('Training and validation loss')
plt.legend()

plt.show()

# %% [markdown]
# ## L2 regulation
# ## 0.61

# %%
import matplotlib.pyplot as plt
import pandas as pd

df = pd.read_csv('history_K_100_aug_5.5_4.csv')

acc = df['acc']


val_acc = df['val_acc']
loss = df['loss']
val_loss = df['val_loss']

epochs = range(len(acc))

plt.plot(epochs, acc, 'bo', label='Training acc')
plt.plot(epochs, val_acc, 'b', label='Validation acc')
plt.title('Training and validation accuracy')
plt.legend()

plt.figure()

plt.plot(epochs, loss, 'bo', label='Training loss')
plt.plot(epochs, val_loss, 'b', label='Validation loss')
plt.title('Training and validation loss')
plt.legend()

plt.show()

# %% [markdown]
# ## shuffle all the images
# ## 0.67

# %%
import matplotlib.pyplot as plt
import pandas as pd

df = pd.read_csv('history_K_100_aug_5.5_5.csv')

acc = df['acc']


val_acc = df['val_acc']
loss = df['loss']
val_loss = df['val_loss']

epochs = range(len(acc))

plt.plot(epochs, acc, 'bo', label='Training acc')
plt.plot(epochs, val_acc, 'b', label='Validation acc')
plt.title('Training and validation accuracy')
plt.legend()

plt.figure()

plt.plot(epochs, loss, 'bo', label='Training loss')
plt.plot(epochs, val_loss, 'b', label='Validation loss')
plt.title('Training and validation loss')
plt.legend()

plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd

df = pd.read_csv('history_K_100_aug_5.5_8.csv')

acc = df['acc']


val_acc = df['val_acc']
loss = df['loss']
val_loss = df['val_loss']

epochs = range(len(acc))

plt.plot(epochs, acc, 'bo', label='Training acc')
plt.plot(epochs, val_acc, 'b', label='Validation acc')
plt.title('Training and validation accuracy')
plt.legend()

plt.figure()

plt.plot(epochs, loss, 'bo', label='Training loss')
plt.plot(epochs, val_loss, 'b', label='Validation loss')
plt.title('Training and validation loss')
plt.legend()

plt.show()
